# %% [markdown]
# # Aufgabenstellung

# %% [markdown]
# Ihr habt in der Vorlesung und in den Tutorials die Grundprinzipien der Datenaufbereitung und Präsentation kennenglernt. Dabei habt ihr unter anderem mit Tableau und mit verschiedenen Python-Bibliothe-
# ken  gearbeitet.  Nutzt  das  erlernte  Wissen  und  die  gesammelten  Daten  aus  Bonuspunkte  Challenge  1
# und 2 und erstellt eine informative Grafik, die uns bis jetzt unerkannte Zusammenhänge zwischen Fr.
# Backs Twitter-Account und ihrer Alexandria-Seite erklärt.
#
# Ziel ist es, die beiden Datensätze aus Bonuspunkte Challenge 1 und 2 so zu analysieren und zu kombinieren, dass sie gemeinsam unerkannte Zusammenhänge aufzeigen.

# %% [markdown]
# #Set up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# Importieren der Tweets von Aback:

# %%
df = pd.read_excel("drive/My Drive/Colab Notebooks/Aback_Tweets.xlsx", sheet_name = 0)

# %% [markdown]
# Importieren der Publikationen von Aback:

# %%
df2 = pd.read_excel("drive/My Drive/Colab Notebooks/Publikationen_Aback.xlsx", sheet_name = 0)

# %% [markdown]
# Mergen der beiden Listen

# %%
df3 = pd.concat([df,df2])
df3
# Out:
#         Datum                                              Tweet  \
# 0  2021-10-10  Check out my latest article: Eine Digitalisier...
# 1  2021-09-25  Reisen bildet: Es gibt nicht nur "die" Freihei...
# 2  2021-09-25  Neue Sprache lernen stand weit zukünftig in me...
# 3  2021-09-21  Beeindruckend-hörenswert-inspirierend, wen @ti...
# 4  2021-09-20  Ist "Remote first" wirklich der Königsweg für ...
# 5  2021-09-17  Wollen Sie hauptsächlich zu Hause (weiter) arb...
# 6  2021-09-17  Sie möchten Ihren Schüler/inn/en Kommunikation...
# 7  2021-09-08  Milano Design Week hat auch abseits der Showro...
# 8  2021-09-06  addendum habe ich vermisst. Nun seit Sept. ein...
# 9  2021-05-19  Heute + morgen je ab 15 Uhr pitchen die insges...
# 10 2021-03-26  Mit Bücherregal als Video-Hintergrund schneide...
# 11 2021-03-25  Welche Jugendliche hätten nicht gerne ein selb...
# 12 2021-03-24  War noch ein wenig unschlüssig, ob Golf wirkli...
# ...

# %% [markdown]
# # Vergleiche

# %% [markdown]
# ### Vergleich: Fragestellung: Wiederspiegeln sich die Themen in den Tweets von Frau Back auch in ihren Publikationen? Dazu erstelle ich eine Wortwolke für die Tweets und die Publikationen

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

text = 'The New Window to Athletes Soul – What Social Media Tells Us About Athletes Performances. How an Incumbent Telecoms Operator Became an IoT Ecosystem Orchestrator. Digital-Entrepreneurship-Werkstatt. Ein Start-up Baukasten für das Klassenzimmer. From Data to Dollar – Using the Wisdom of an Online Tipster Community to Improve Sports Betting Returns. Innovation durch den Einsatz von Enterprise. Konfrontiert mit einer Flut von Kooperations­anfragen: So meistern Sportorganisationen die systematische Analyse und Bearbeitung. From Suppliers to Complementors: Motivational Factors for Joining Industrial Internet of Things Platform Ecosystems. Die Kinder üben eine Denkhaltung. Erfolgsfaktoren für digitale Solutions: Wie steht es um die Innovationskultur in Ihrem Unternehmen? Steuerungstool des Board of Directors für Digitale Transformationsprojekte'

nichtinteressant = "und von Der das den wir ist die auf im für zu ich ein auch sich hat mit Sie als mich nicht wie"
liste_der_unerwuenschten_woerter = nichtinteressant.split()

STOPWORDS.update(liste_der_unerwuenschten_woerter)
wordcloud = WordCloud(background_color="white").generate(text)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

text = 'Check out my latest article: Eine Digitalisierungsstrategie entwickeln als KMU und mit Agile Mindset. Reisen bildet: Es gibt nicht nur "die" Freiheitsstatue; (auch Google Bilder liefert nur die bekannten Bilder). Auf dem Gellertberg ist weithin diejenige von Ungarn zu sehen. Ich finde sie anmutig - hat mich zum Nachtspaziergang veranlasst. Neue Sprache lernen stand weit zukünftig in meinem MySevenYearPlan. "Due to recent major world events ..." (Formulierung im Hotel Parisi, Budapest, gesehen) konnte ich das Vorhaben auf 21 vorziehen. Era una martona, von nahe Null auf B1, aber geschafft. Beeindruckend-hörenswert-inspirierend, wen @time4youGmbH alles vor Linse&amp;Mikrofon holt, zuletzt J. Vidarte, Generaldirektor Guggenheim Museum Bilbao. Seit Frühjahr - nach Videoformat Tell Me How You Learn - nun auch Podcast. Ist "Remote first" wirklich der Königsweg für die Arbeitsortreglungen? Studienergebnisse wie diese erwarte ich noch weitere:  https://t.co/oUYjYdlNvw. Nadella nennt Wunsch der Mitarbeitenden nach Flexibility und zugleich Connectedness: "The Great Paradox", heisst es im Artikel. Wollen Sie hauptsächlich zu Hause (weiter) arbeiten? Das hängt ja auch von der Bürogestaltung ab. Meine Kolumne: "Arbeitswohnzimmer im Büro" stellt Einrichtungswünsche vor, damit ich mich gerne auf den Weg mache. Sie möchten Ihren Schüler/inn/en Kommunikation&amp;Präsentation mit Storytelling und digitalen Medien ermöglichen? Hier alles was Sie dafür brauchen, um - gleich welches Fach - ein Unterrichtsmodul damit zu gestalten (Erklärvidos, PDFs, etc.). Milano Design Week hat auch abseits der Showrooms was zu entdecken, wie hier Verkehrsschilder im Brera Viertel. addendum habe ich vermisst. Nun seit Sept. ein neues vielversprechendes Medienprodukt: Fakten - Vestehen - Handeln, online &amp; print:  https://t.co/DPNU6Rr8BC. Erstes Dossier e-Autos. (Mit Erregungsjournalismus, Verkürzung und Zuspitzung, graben sich Zeitungen selbst ihr Grab, m.E.). Heute + morgen je ab 15 Uhr pitchen die insgesamt 15 Award-Nominees für die Smart-IoT- und Mobile Business Awards.  https://t.co/ymuX9uvPjW Mehr Infos + Anmeldemöglichkeit, auch für morgige IoT-Workshops von Ergon und HPE (freierZugang zu Online-Event). Mit Bücherregal als Video-Hintergrund schneidet man bei Persönlichkeitsmerkmals-Einschätzungen besser ab - bei einer KI jedenfalls . Experimente mit kurzen Bewerbungsvideos. Welche Jugendliche hätten nicht gerne ein selbst gestaltetes LED-TShirt? Das @smartfeld SmartTShirt-Projekt ist nun OpenSource - Packen Sie es an, als Lehrperson oder Schüler/innen peer-to-peer. War noch ein wenig unschlüssig, ob Golf wirklich ein Sport für mich ist, den ich lernen will. Die 2 Bilder im FJ-21 Golfers Paradise Magazin GROOVES, CH,  räumen Zweifel aus: Ganz klar ein Frauensport - Handicap nicht so wichtig .... (Braucht #werbung das: #sexismus in 2021?). Mein Sprachassistent Google Home versteht mich in jüngster Zeit schlechter als auch schon - können Algorithem an Zuviel (Daten) kippen? Wie Ökosysteme? So jedenfalls die Vermutung in meiner Kolumne: Das Web hat ein Messie Syndrom. Wüstensand aus Afrika auf Schnee in den Schweizer Alpen. Die Natur ist auf Vereinigung +Überwinden von Grenzen aus. Steht der #Diavolezza Teufelin gut.  #InLovewithSwitzeland #Daycatcher. Stolz auf Ihre Mobile Solution oder IoT-Solution? Dann wird es Zeit für eine Einreichung zu den beiden Awards - Frist ist 12. März - nur noch 2 Wochen. Eine intl. Top-Jury bestimmt die Nominees. Stimme zu! Dass jede/r Content beitragen kann, darf nicht Assoziationen zu Littering oder Messie-tum wecken. Meine Kolumne über die "Messie-Ecken" ist ja als "Was sich liebt, das neckt sich" zu verstehen. Zudem hat Wikipedia eine Lösung zu: Wissen veraltet: die Banner-Nudges. Mal wieder Gänsehaut gekriegt, gestern #PerseveranceMars  die 7 minutes of terror mitverfolgt (Hintergrundinfos hier:  https://t.co/WXwZiJZ4Rz). Und die Erinnerung an 1969 als Kind vor dem Fernseher zu sitzen, fühlte sich ganz frisch an. @sms2sms Oh, habe ich jemanden beleidigt? Ja, gerne. Dann verstehe ich, was du meinst. (Die Kolumnen schreibe ich ja auch mit Augenzwinkern - dachte bei dieser, dass einige denken, wie doof ich mich wohl anstelle, nur wird mir das kaum jemand schreiben. Vorerst auf Eis gelegt: Twitter hat bei mir als Arbeitsmittel an Bedeutung verloren, ist mir aufgefallen. Es ist kaum mehr Fundgrube für Wissen, Quelle für neue Fachkontakte, und die Lektüre hat mir auch schon mehr gefallen. So lasse ich es einfach mal eine lange Weile ruhen.'

nichtinteressant = "und von Der das den wir ist die auf im für zu ich ein auch sich hat mit Sie als mich nicht wie"
liste_der_unerwuenschten_woerter = nichtinteressant.split()

STOPWORDS.update(liste_der_unerwuenschten_woerter)
wordcloud = WordCloud(background_color="white").generate(text)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# Aus der Wortwolke der Publikationen kann darauf geschlossen werden, dass  Prof. Backs Themengebiete in den Bereichen digital / Ecosysteme / Social Media angesiedelt sind. Dies lässt sich jedoch nur begrenzt mit der Wortwolke der Tweets bestätigen bzw. wiederspiegeln.
