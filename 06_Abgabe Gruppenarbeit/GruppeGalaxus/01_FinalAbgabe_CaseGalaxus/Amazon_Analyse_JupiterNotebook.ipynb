# %% [markdown]
# #Analyse Amazon
# Im folgenden Jupiter Notebook wird der Datensatz der gecrawlten Amazon Webseite (www.amazon.de) Schritt für Schritt analysiert und entsprechende Schlüsse daraus gezogen. In einem ersten Arbeitsschritt wird das Datenset eingelesen und die enthaltenen Datentypen analysiert

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "drive/MyDrive/Colab Notebooks"

# %% [markdown]
# ## Einlesen des Datensets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Amazon = pd.read_excel("drive/MyDrive/Colab Notebooks/amazonbestseller_merge.xlsx")

# %% [markdown]
# ## 1) Analysieren des Datensets

# %% [markdown]
# ### Variablen und Instances des Datenset

# %%
Amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10228 entries, 0 to 10227
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Datum         10228 non-null  datetime64[ns]
#  1   Kategorien    10228 non-null  object
#  2   Produkt Name  7559 non-null   object
#  3   Preis         9126 non-null   float64
#  4   Ranking       10228 non-null  float64
#  5   Preis Max.    4980 non-null   object
#  6   Reviews       8096 non-null   float64
#  7   Bewertung     9892 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 639.4+ KB

# %% [markdown]
# ### Datentypen

# %% [markdown]
# Im Datenset sind drei verschiedene Datentypen vorhanden. Erkennbar ist dies an der Linie "dtypes: datetime64(ns)(1), float64(4), object(3), " - In der Klammer ist ersichtlich, wie viele Variablen diesem Datentyp zugeordnet sind.
# - datetime64 beschreibt dabei ein Zeit- und Uhrzeitformat
# - float64 fassen Zahlen mit Gleitkomma Zahlenformat zusammen
# - Object, auch String genannt, ist eine Kombination aus Zahlen oder/und Buchstaben (Zeichenketten) und muss immer in Gänsefüsschen ""/'' geschrieben werden

# %% [markdown]
# ### Daten untersuchen

# %%
Amazon.head()
# Out:
#        Datum        Kategorien  \
# 0 2022-04-08  Amazon Launchpad
# 1 2022-04-08  Large Appliances
# 2 2022-04-08      Kindle Store
# 3 2022-04-08        Automotive
# 4 2022-04-08      Apps & Games
#
#                                         Produkt Name  Preis  Ranking  \
# 0              Magilano SKYJO Action Card Game, 19,4  14.06      1.0
# 1  TFA Dostmann Analoges Kühlthermometer, klein, ...   3.98     19.0
# 2                                                NaN   2.99      7.0
# 3                  Foliatec Brake Calliper Paint Set  22.11      8.0
# 4                                                NaN   2.19     22.0
#
#   Preis Max.  Reviews  Bewertung
# 0      33.95  31084.0        4.8
# 1        NaN   5520.0        4.4
# 2        NaN   7562.0        4.2
# 3       48.0  11671.0        4.6
# 4        NaN      NaN        4.3

# %% [markdown]
# Diese Funktion gibt die ersten fünf Zeilen des Datensets aus.

# %% [markdown]
# ### Überprüfen der Anzahl der Datensätze

# %%
len(Amazon)
# Out:
# 10228

# %% [markdown]
# Total sind somit 10228 Produkte im Zeitraum vom 8. April - 16. April 2022 gescraped worden

# %%
Amazon.dtypes
# Out:
# Datum           datetime64[ns]
# Kategorien              object
# Produkt Name            object
# Preis                  float64
# Ranking                float64
# Preis Max.              object
# Reviews                float64
# Bewertung              float64
# dtype: object

# %% [markdown]
# Im Gegensatz zum ursprünglichen Galaxus-Datensatz sind alle Werte dem richtigen Datentyp zugeordnet und es sind keine weiteren Datenanpassungen nötig.

# %% [markdown]
# ## 2) Diverse Fragestellungen

# %% [markdown]
# ### Preisanalyse

# %%
Amazon.hist(column=["Preis"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa9dedae1d0>]],
#       dtype=object)

# %%
Amazon.hist(column="Preis", bins=10000, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9);

# %% [markdown]
# Mittels des Histogrammes ist ersichtlich, dass die meisten Produkte in einem Preisrange von 0.9 - 100 Fr. liegen. Die tiefsten und höchsten Werte sind wie folgt:

# %%
Amazon.Preis.min()
# Out:
# 0.88

# %%
Amazon.Preis.max()
# Out:
# 770.91
